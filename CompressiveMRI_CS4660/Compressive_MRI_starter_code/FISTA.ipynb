# %% [markdown]
# # Compressed Sensing MRI
#
# Python Starter Code for Prof. Miki Lustig's Compressive Sensing MRI assignment. https://people.eecs.berkeley.edu/~mlustig/CS.html

# %%
import numpy as np
import torch
import torch.nn as nn
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from torchvision.datasets import ImageNet
import matplotlib.pyplot as plt
import scipy.io
import pywt
from scipy.fft import fft, ifft, fft2, ifft2, fftshift, ifftshift
from IPython.display import clear_output
from inverse_solver import InverseSolver
import inverse_solver
import deepinv as dinv
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Helper Functions
#
# These functions are provided for you. Run this cell before proceeding.

# %%
def fftc(x, axis=-1):
    """Centered 1D FFT with orthonormal scaling."""
    N = x.shape[axis]
    return fftshift(fft(ifftshift(x, axes=axis), axis=axis), axes=axis) / np.sqrt(N)


def ifftc(x, axis=-1):
    """Centered 1D inverse FFT with orthonormal scaling."""
    N = x.shape[axis]
    return fftshift(ifft(ifftshift(x, axes=axis), axis=axis), axes=axis) * np.sqrt(N)


def fft2c(x):
    """Centered 2D FFT with orthonormal scaling."""
    return fftshift(fft2(ifftshift(x))) / np.sqrt(x.size)


def ifft2c(x):
    """Centered 2D inverse FFT with orthonormal scaling."""
    return fftshift(ifft2(ifftshift(x))) * np.sqrt(x.size)


print("✓ Helper functions loaded!")
# Out:
# ✓ Helper functions loaded!

# %% [markdown]
# Take the origional Model from this:
# -Denoising: Soft thresholding
# -Forward Model: Wavelet
# -Inverse Model: POCS
#
# And make the following changes to compare:
# -Denoising: Soft thresholding + Plug and Play Priors
# -Forward Model: Wavelet
# -Inverse Model: FISTA (Tv)

# %% [markdown]
# ### PnP (Plug-and-Play Prior Setup)

# %%
model = dinv.models.DRUNet()
model.eval()


def PnPDenoiser(x, sigma=0.1):
    with torch.no_grad():
        x_input = torch.from_numpy(x)[None, None].to(device, dtype=torch.float32)
        x_denoised = model(x_input, sigma)
        return x_denoised.squeeze().cpu().numpy().clip(0, 1)

# %%
data = scipy.io.loadmat("brain.mat")

im = np.abs(data["im"] / np.max(data["im"]))
mask = data["mask_vardens"]
pdf = data["pdf_vardens"]

plt.imshow(np.abs(im), cmap="gray")
plt.title("Original Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(511.5), np.float64(511.5), np.float64(-0.5))

# %%
def A(x, mask):
    """Forward operator: FFT + Undersampling Mask"""
    # MRI samples in k-space (Fourier domain)
    kspace = fft2c(x)
    return kspace * mask


def A_adjoint(kspace_masked, mask):
    """Adjoint operator: Mask + IFFT"""
    # Back to image domain
    res = kspace_masked * mask
    return ifft2c(res)


def soft_thresh(z, threshold):
    """Soft-thresholding operator.

    Shrinks all values toward zero by `threshold`. Values with
    magnitude less than `threshold` become exactly zero:

        soft(z, t) = sign(z) * max(|z| - t, 0)

    Args:
        z: Input array
        threshold: Threshold value (>= 0)
    Returns:
        Soft-thresholded array (same shape as z)
    """
    return np.sign(z) * np.maximum(np.abs(z) - threshold, 0)


def prox_wavelet(x, lam):
    """Wavelet-domain soft thresholding."""
    coeffs = pywt.wavedec2(x, wavelet="db4", mode="periodization", level=4)
    # Apply thresholding to all coefficient levels
    coeffs_thresh = [coeffs[0]]  # Keep approximation coefficients
    for detail_level in coeffs[1:]:
        coeffs_thresh.append(tuple(soft_thresh(c, lam) for c in detail_level))
    return pywt.waverec2(coeffs_thresh, wavelet="db4", mode="periodization")

# %%
model = dinv.models.DRUNet(pretrained="download")
model.eval()


def PnPDenoiser(x, model, sigma=0.01):
    """DRUNet Denoising with channel padding to avoid RuntimeError"""
    x_real = np.real(x).astype(np.float32)
    with torch.no_grad():
        x_tensor = torch.from_numpy(x_real).unsqueeze(0).unsqueeze(0).to(device)
        x_padded = F.pad(x_tensor, (0, 0, 0, 0, 0, 2))
        s = torch.tensor([sigma]).to(device)
        denoised_padded = model(x_padded, s)
        return denoised_padded[0, 0, :, :].cpu().numpy()

# %%
def contractive_denoiser(x, model, sigma, alpha, L=0.9):
    """
    Enforces near-nonexpansiveness:
    - alpha: averaging strength (<= 1)
    - L: global Lipschitz shrink (< 1 for contraction)
    """
    Dx = PnPDenoiser(x, model, sigma)

    # residual contraction
    D_res = x + alpha * (Dx - x)

    # global Lipschitz clamp
    return L * D_res + (1 - L) * x


def estimate_lipschitz(mask, num_iter=30):
    """
    Estimate spectral norm of A*A via power iteration.
    A*A x = IFFT(mask * FFT(x))
    """
    # Random init
    x = np.random.randn(*mask.shape) + 1j * np.random.randn(*mask.shape)
    x /= np.linalg.norm(x)

    for _ in range(num_iter):
        # Apply A*A
        x_new = A_adjoint(A(x, mask), mask)  # your existing operators

        # Rayleigh quotient → eigenvalue estimate
        L = np.linalg.norm(x_new)
        x = x_new / L

    return L


def fista_reconstruct(y, mask, im_gt, iterations=100, lam=0.005):
    """
    y: K-space measurements
    mask: Sampling mask
    im_gt: Ground truth (for error tracking)
    model: Pre-trained DRUNet
    """
    x = np.zeros_like(im_gt)
    v = np.zeros_like(x)
    t = 1.0
    L = estimate_lipschitz(mask)
    step_size = 1.0 / L

    error_history = []

    for i in range(iterations):
        x_old = x.copy()

        grad = A_adjoint(A(v, mask) - y, mask)
        z = v - step_size * grad

        x = soft_thresh(z, lam)

        t_next = (1 + np.sqrt(1 + 4 * t**2)) / 2
        v = x + ((t - 1) / t_next) * (x - x_old)
        t = t_next

        rel_error = np.linalg.norm(np.abs(x) - im_gt) / np.linalg.norm(im_gt)
        error_history.append(rel_error)
        if (i + 1) % 10 == 0:
            print(f"Iteration {i+1}/{iterations} - Error: {rel_error:.6f}")
    return x, error_history

# %% [markdown]
# Final Image

# %%
y_measured = A(im, mask)
lambdas = [5e-5, 1e-4, 5e-4, 1e-3, 5e-3, 1e-2, 5e-2]
key = lambdas[2]

reconstructed, error_log = fista_reconstruct(
    y_measured, mask, im, iterations=900, lam=key
)

# Display results
plt.figure(figsize=(15, 5))

plt.subplot(1, 4, 1)
plt.imshow(np.abs(im), cmap="gray")
plt.title("Original MRI")
plt.axis("off")

plt.subplot(1, 4, 2)
plt.imshow(np.abs(reconstructed), cmap="gray")
plt.title(f"FISTA Recon (λ={key})\nmin err={np.min(error_log)}")
plt.axis("off")

plt.subplot(1, 4, 3)
plt.plot(error_log)
plt.title("Error Over Iterations")
plt.xlabel("Iteration")
plt.ylabel("Relative Error")

plt.subplot(1, 4, 4)
plt.plot(error_log)
plt.ylim([0.07, 0.1])
plt.title("Error Over Iterations")
plt.xlabel("Iteration")
plt.ylabel("Relative Error")

plt.tight_layout()
plt.show()
# Out:
# Iteration 10/900 - Error: 0.094638
# Iteration 20/900 - Error: 0.093359
# Iteration 30/900 - Error: 0.091560
# Iteration 40/900 - Error: 0.089463
# Iteration 50/900 - Error: 0.087301
# Iteration 60/900 - Error: 0.085260
# Iteration 70/900 - Error: 0.083460
# Iteration 80/900 - Error: 0.081957
# Iteration 90/900 - Error: 0.080755
# Iteration 100/900 - Error: 0.079820
# Iteration 110/900 - Error: 0.079102
# Iteration 120/900 - Error: 0.078548
# Iteration 130/900 - Error: 0.078112
# Iteration 140/900 - Error: 0.077755
# Iteration 150/900 - Error: 0.077455
# Iteration 160/900 - Error: 0.077193
# Iteration 170/900 - Error: 0.076962
# Iteration 180/900 - Error: 0.076756
# Iteration 190/900 - Error: 0.076573
# Iteration 200/900 - Error: 0.076411
# Iteration 210/900 - Error: 0.076270
# Iteration 220/900 - Error: 0.076148
# Iteration 230/900 - Error: 0.076044
# Iteration 240/900 - Error: 0.075955
# Iteration 250/900 - Error: 0.075881
# Iteration 260/900 - Error: 0.075819
# Iteration 270/900 - Error: 0.075768
# Iteration 280/900 - Error: 0.075725
# Iteration 290/900 - Error: 0.075691
# Iteration 300/900 - Error: 0.075662
# Iteration 310/900 - Error: 0.075638
# Iteration 320/900 - Error: 0.075618
# Iteration 330/900 - Error: 0.075601
# Iteration 340/900 - Error: 0.075586
# Iteration 350/900 - Error: 0.075573
# Iteration 360/900 - Error: 0.075560
# Iteration 370/900 - Error: 0.075548
# Iteration 380/900 - Error: 0.075537
# Iteration 390/900 - Error: 0.075526
# Iteration 400/900 - Error: 0.075514
# Iteration 410/900 - Error: 0.075503
# Iteration 420/900 - Error: 0.075492
# Iteration 430/900 - Error: 0.075481
# Iteration 440/900 - Error: 0.075470
# Iteration 450/900 - Error: 0.075460
# Iteration 460/900 - Error: 0.075449
# Iteration 470/900 - Error: 0.075440
# Iteration 480/900 - Error: 0.075430
# Iteration 490/900 - Error: 0.075422
# Iteration 500/900 - Error: 0.075414
# Iteration 510/900 - Error: 0.075407
# Iteration 520/900 - Error: 0.075400
# Iteration 530/900 - Error: 0.075395
# Iteration 540/900 - Error: 0.075390
# Iteration 550/900 - Error: 0.075385
# Iteration 560/900 - Error: 0.075381
# Iteration 570/900 - Error: 0.075377
# Iteration 580/900 - Error: 0.075374
# Iteration 590/900 - Error: 0.075371
# Iteration 600/900 - Error: 0.075369
# Iteration 610/900 - Error: 0.075366
# Iteration 620/900 - Error: 0.075364
# Iteration 630/900 - Error: 0.075362
# Iteration 640/900 - Error: 0.075360
# Iteration 650/900 - Error: 0.075358
# Iteration 660/900 - Error: 0.075356
# Iteration 670/900 - Error: 0.075354
# Iteration 680/900 - Error: 0.075352
# Iteration 690/900 - Error: 0.075350
# Iteration 700/900 - Error: 0.075348
# Iteration 710/900 - Error: 0.075347
# Iteration 720/900 - Error: 0.075345
# Iteration 730/900 - Error: 0.075343
# Iteration 740/900 - Error: 0.075342
# Iteration 750/900 - Error: 0.075340
# Iteration 760/900 - Error: 0.075339
# Iteration 770/900 - Error: 0.075337
# Iteration 780/900 - Error: 0.075336
# Iteration 790/900 - Error: 0.075335
# Iteration 800/900 - Error: 0.075333
# Iteration 810/900 - Error: 0.075332
# Iteration 820/900 - Error: 0.075331
# Iteration 830/900 - Error: 0.075330
# Iteration 840/900 - Error: 0.075329
# Iteration 850/900 - Error: 0.075328
# Iteration 860/900 - Error: 0.075328
# Iteration 870/900 - Error: 0.075327
# Iteration 880/900 - Error: 0.075326
# Iteration 890/900 - Error: 0.075326
# Iteration 900/900 - Error: 0.075325

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(np.abs(im), cmap="gray")
plt.title("Original MRI")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(np.abs(reconstructed), cmap="gray")
plt.title(f"FISTA + PnP Reconf\nerr={error_log[-1]:.3f}")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.plot(error_log)
plt.title("Error Over Iterations")
plt.xlabel("Iteration")
plt.ylabel("Relative Error")
# Out:
# Text(0, 0.5, 'Relative Error')

# %%
plt.figure()
plt.plot(error_log)
plt.ylim([0.07, 0.1])
plt.title("Error Over Iterations")
plt.xlabel("Iteration")
plt.ylabel("Relative Error")

plt.tight_layout()
plt.show()

# %%
y_measured = A(im, mask)
lambdas = [5e-5, 1e-4, 5e-4, 1e-3, 5e-3, 1e-2, 5e-2]

min_error_sweep = []

for lam in lambdas:
    reconstructed, error_log = fista_reconstruct(
        y_measured, mask, im, iterations=1000, lam=lam
    )
    min_error_sweep.append(np.min(error_log))

plt.semilogx(lambdas, min_error_sweep, marker="o")
plt.xlabel("lambda")
plt.ylabel("min error")
plt.title("FISTA lambda sweep")
plt.grid(True)
plt.show()
# Out:
# Iteration 10/1000 - Error: 0.095167
# Iteration 20/1000 - Error: 0.095029
# Iteration 30/1000 - Error: 0.094817
# Iteration 40/1000 - Error: 0.094533
# Iteration 50/1000 - Error: 0.094182
# Iteration 60/1000 - Error: 0.093769
# Iteration 70/1000 - Error: 0.093297
# Iteration 80/1000 - Error: 0.092774
# Iteration 90/1000 - Error: 0.092206
# Iteration 100/1000 - Error: 0.091599
# Iteration 110/1000 - Error: 0.090961
# Iteration 120/1000 - Error: 0.090299
# Iteration 130/1000 - Error: 0.089622
# Iteration 140/1000 - Error: 0.088937
# Iteration 150/1000 - Error: 0.088249
# Iteration 160/1000 - Error: 0.087567
# Iteration 170/1000 - Error: 0.086894
# Iteration 180/1000 - Error: 0.086236
# Iteration 190/1000 - Error: 0.085598
# Iteration 200/1000 - Error: 0.084982
# Iteration 210/1000 - Error: 0.084391
# Iteration 220/1000 - Error: 0.083828
# Iteration 230/1000 - Error: 0.083295
# Iteration 240/1000 - Error: 0.082792
# Iteration 250/1000 - Error: 0.082319
# Iteration 260/1000 - Error: 0.081878
# Iteration 270/1000 - Error: 0.081467
# Iteration 280/1000 - Error: 0.081086
# Iteration 290/1000 - Error: 0.080733
# Iteration 300/1000 - Error: 0.080408
# Iteration 310/1000 - Error: 0.080108
# Iteration 320/1000 - Error: 0.079831
# Iteration 330/1000 - Error: 0.079578
# Iteration 340/1000 - Error: 0.079344
# Iteration 350/1000 - Error: 0.079130
# Iteration 360/1000 - Error: 0.078932
# Iteration 370/1000 - Error: 0.078750
# Iteration 380/1000 - Error: 0.078582
# Iteration 390/1000 - Error: 0.078426
# Iteration 400/1000 - Error: 0.078281
# Iteration 410/1000 - Error: 0.078146
# Iteration 420/1000 - Error: 0.078020
# Iteration 430/1000 - Error: 0.077901
# Iteration 440/1000 - Error: 0.077789
# Iteration 450/1000 - Error: 0.077683
# Iteration 460/1000 - Error: 0.077583
# Iteration 470/1000 - Error: 0.077487
# Iteration 480/1000 - Error: 0.077395
# Iteration 490/1000 - Error: 0.077307
# Iteration 500/1000 - Error: 0.077223
# Iteration 510/1000 - Error: 0.077142
# Iteration 520/1000 - Error: 0.077064
# Iteration 530/1000 - Error: 0.076989
# Iteration 540/1000 - Error: 0.076916
# Iteration 550/1000 - Error: 0.076846
# Iteration 560/1000 - Error: 0.076779
# Iteration 570/1000 - Error: 0.076714
# Iteration 580/1000 - Error: 0.076651
# Iteration 590/1000 - Error: 0.076591
# Iteration 600/1000 - Error: 0.076533
# Iteration 610/1000 - Error: 0.076477
# Iteration 620/1000 - Error: 0.076423
# Iteration 630/1000 - Error: 0.076371
# Iteration 640/1000 - Error: 0.076322
# Iteration 650/1000 - Error: 0.076274
# Iteration 660/1000 - Error: 0.076229
# Iteration 670/1000 - Error: 0.076185
# Iteration 680/1000 - Error: 0.076143
# Iteration 690/1000 - Error: 0.076104
# Iteration 700/1000 - Error: 0.076066
# Iteration 710/1000 - Error: 0.076030
# Iteration 720/1000 - Error: 0.075996
# Iteration 730/1000 - Error: 0.075964
# Iteration 740/1000 - Error: 0.075933
# Iteration 750/1000 - Error: 0.075904
# Iteration 760/1000 - Error: 0.075876
# Iteration 770/1000 - Error: 0.075850
# Iteration 780/1000 - Error: 0.075826
# Iteration 790/1000 - Error: 0.075802
# Iteration 800/1000 - Error: 0.075780
# Iteration 810/1000 - Error: 0.075760
# Iteration 820/1000 - Error: 0.075740
# Iteration 830/1000 - Error: 0.075722
# Iteration 840/1000 - Error: 0.075705
# Iteration 850/1000 - Error: 0.075688
# Iteration 860/1000 - Error: 0.075673
# Iteration 870/1000 - Error: 0.075658
# Iteration 880/1000 - Error: 0.075645
# Iteration 890/1000 - Error: 0.075632
# Iteration 900/1000 - Error: 0.075620
# Iteration 910/1000 - Error: 0.075609
# Iteration 920/1000 - Error: 0.075598
# Iteration 930/1000 - Error: 0.075588
# Iteration 940/1000 - Error: 0.075579
# Iteration 950/1000 - Error: 0.075570
# Iteration 960/1000 - Error: 0.075562
# Iteration 970/1000 - Error: 0.075554
# Iteration 980/1000 - Error: 0.075547
# Iteration 990/1000 - Error: 0.075540
# Iteration 1000/1000 - Error: 0.075533
# Iteration 10/1000 - Error: 0.095107
# Iteration 20/1000 - Error: 0.094834
# Iteration 30/1000 - Error: 0.094417
# Iteration 40/1000 - Error: 0.093869
# Iteration 50/1000 - Error: 0.093203
# Iteration 60/1000 - Error: 0.092436
# Iteration 70/1000 - Error: 0.091586
# Iteration 80/1000 - Error: 0.090676
# Iteration 90/1000 - Error: 0.089725
# Iteration 100/1000 - Error: 0.088755
# Iteration 110/1000 - Error: 0.087786
# Iteration 120/1000 - Error: 0.086834
# Iteration 130/1000 - Error: 0.085912
# Iteration 140/1000 - Error: 0.085033
# Iteration 150/1000 - Error: 0.084204
# Iteration 160/1000 - Error: 0.083431
# Iteration 170/1000 - Error: 0.082719
# Iteration 180/1000 - Error: 0.082069
# Iteration 190/1000 - Error: 0.081480
# Iteration 200/1000 - Error: 0.080950
# Iteration 210/1000 - Error: 0.080475
# Iteration 220/1000 - Error: 0.080053
# Iteration 230/1000 - Error: 0.079678
# Iteration 240/1000 - Error: 0.079345
# Iteration 250/1000 - Error: 0.079049
# Iteration 260/1000 - Error: 0.078785
# Iteration 270/1000 - Error: 0.078550
# Iteration 280/1000 - Error: 0.078339
# Iteration 290/1000 - Error: 0.078148
# Iteration 300/1000 - Error: 0.077974
# Iteration 310/1000 - Error: 0.077814
# Iteration 320/1000 - Error: 0.077666
# Iteration 330/1000 - Error: 0.077529
# Iteration 340/1000 - Error: 0.077400
# Iteration 350/1000 - Error: 0.077279
# Iteration 360/1000 - Error: 0.077165
# Iteration 370/1000 - Error: 0.077056
# Iteration 380/1000 - Error: 0.076953
# Iteration 390/1000 - Error: 0.076856
# Iteration 400/1000 - Error: 0.076763
# Iteration 410/1000 - Error: 0.076674
# Iteration 420/1000 - Error: 0.076591
# Iteration 430/1000 - Error: 0.076511
# Iteration 440/1000 - Error: 0.076436
# Iteration 450/1000 - Error: 0.076365
# Iteration 460/1000 - Error: 0.076299
# Iteration 470/1000 - Error: 0.076236
# Iteration 480/1000 - Error: 0.076177
# Iteration 490/1000 - Error: 0.076122
# Iteration 500/1000 - Error: 0.076071
# Iteration 510/1000 - Error: 0.076023
# Iteration 520/1000 - Error: 0.075979
# Iteration 530/1000 - Error: 0.075938
# Iteration 540/1000 - Error: 0.075900
# Iteration 550/1000 - Error: 0.075864
# Iteration 560/1000 - Error: 0.075832
# Iteration 570/1000 - Error: 0.075802
# Iteration 580/1000 - Error: 0.075774
# Iteration 590/1000 - Error: 0.075749
# Iteration 600/1000 - Error: 0.075726
# Iteration 610/1000 - Error: 0.075704
# Iteration 620/1000 - Error: 0.075685
# Iteration 630/1000 - Error: 0.075667
# Iteration 640/1000 - Error: 0.075650
# Iteration 650/1000 - Error: 0.075635
# Iteration 660/1000 - Error: 0.075622
# Iteration 670/1000 - Error: 0.075609
# Iteration 680/1000 - Error: 0.075598
# Iteration 690/1000 - Error: 0.075587
# Iteration 700/1000 - Error: 0.075577
# Iteration 710/1000 - Error: 0.075568
# Iteration 720/1000 - Error: 0.075560
# Iteration 730/1000 - Error: 0.075552
# Iteration 740/1000 - Error: 0.075544
# Iteration 750/1000 - Error: 0.075537
# Iteration 760/1000 - Error: 0.075531
# Iteration 770/1000 - Error: 0.075524
# Iteration 780/1000 - Error: 0.075518
# Iteration 790/1000 - Error: 0.075512
# Iteration 800/1000 - Error: 0.075507
# Iteration 810/1000 - Error: 0.075501
# Iteration 820/1000 - Error: 0.075496
# Iteration 830/1000 - Error: 0.075490
# Iteration 840/1000 - Error: 0.075485
# Iteration 850/1000 - Error: 0.075480
# Iteration 860/1000 - Error: 0.075475
# Iteration 870/1000 - Error: 0.075470
# Iteration 880/1000 - Error: 0.075464
# Iteration 890/1000 - Error: 0.075459
# Iteration 900/1000 - Error: 0.075454
# Iteration 910/1000 - Error: 0.075449
# Iteration 920/1000 - Error: 0.075444
# Iteration 930/1000 - Error: 0.075439
# Iteration 940/1000 - Error: 0.075434
# Iteration 950/1000 - Error: 0.075429
# Iteration 960/1000 - Error: 0.075424
# Iteration 970/1000 - Error: 0.075419
# Iteration 980/1000 - Error: 0.075414
# Iteration 990/1000 - Error: 0.075409
# Iteration 1000/1000 - Error: 0.075404
# Iteration 10/1000 - Error: 0.094638
# Iteration 20/1000 - Error: 0.093359
# Iteration 30/1000 - Error: 0.091560
# Iteration 40/1000 - Error: 0.089463
# Iteration 50/1000 - Error: 0.087301
# Iteration 60/1000 - Error: 0.085260
# Iteration 70/1000 - Error: 0.083460
# Iteration 80/1000 - Error: 0.081957
# Iteration 90/1000 - Error: 0.080755
# Iteration 100/1000 - Error: 0.079820
# Iteration 110/1000 - Error: 0.079102
# Iteration 120/1000 - Error: 0.078548
# Iteration 130/1000 - Error: 0.078112
# Iteration 140/1000 - Error: 0.077755
# Iteration 150/1000 - Error: 0.077455
# Iteration 160/1000 - Error: 0.077193
# Iteration 170/1000 - Error: 0.076962
# Iteration 180/1000 - Error: 0.076756
# Iteration 190/1000 - Error: 0.076573
# Iteration 200/1000 - Error: 0.076411
# Iteration 210/1000 - Error: 0.076270
# Iteration 220/1000 - Error: 0.076148
# Iteration 230/1000 - Error: 0.076044
# Iteration 240/1000 - Error: 0.075955
# Iteration 250/1000 - Error: 0.075881
# Iteration 260/1000 - Error: 0.075819
# Iteration 270/1000 - Error: 0.075768
# Iteration 280/1000 - Error: 0.075725
# Iteration 290/1000 - Error: 0.075691
# Iteration 300/1000 - Error: 0.075662
# Iteration 310/1000 - Error: 0.075638
# Iteration 320/1000 - Error: 0.075618
# Iteration 330/1000 - Error: 0.075601
# Iteration 340/1000 - Error: 0.075586
# Iteration 350/1000 - Error: 0.075573
# Iteration 360/1000 - Error: 0.075560
# Iteration 370/1000 - Error: 0.075548
# Iteration 380/1000 - Error: 0.075537
# Iteration 390/1000 - Error: 0.075526
# Iteration 400/1000 - Error: 0.075514
# Iteration 410/1000 - Error: 0.075503
# Iteration 420/1000 - Error: 0.075492
# Iteration 430/1000 - Error: 0.075481
# Iteration 440/1000 - Error: 0.075470
# Iteration 450/1000 - Error: 0.075460
# Iteration 460/1000 - Error: 0.075449
# Iteration 470/1000 - Error: 0.075440
# Iteration 480/1000 - Error: 0.075430
# Iteration 490/1000 - Error: 0.075422
# Iteration 500/1000 - Error: 0.075414
# Iteration 510/1000 - Error: 0.075407
# Iteration 520/1000 - Error: 0.075400
# Iteration 530/1000 - Error: 0.075395
# Iteration 540/1000 - Error: 0.075390
# Iteration 550/1000 - Error: 0.075385
# Iteration 560/1000 - Error: 0.075381
# Iteration 570/1000 - Error: 0.075377
# Iteration 580/1000 - Error: 0.075374
# Iteration 590/1000 - Error: 0.075371
# Iteration 600/1000 - Error: 0.075369
# Iteration 610/1000 - Error: 0.075366
# Iteration 620/1000 - Error: 0.075364
# Iteration 630/1000 - Error: 0.075362
# Iteration 640/1000 - Error: 0.075360
# Iteration 650/1000 - Error: 0.075358
# Iteration 660/1000 - Error: 0.075356
# Iteration 670/1000 - Error: 0.075354
# Iteration 680/1000 - Error: 0.075352
# Iteration 690/1000 - Error: 0.075350
# Iteration 700/1000 - Error: 0.075348
# Iteration 710/1000 - Error: 0.075347
# Iteration 720/1000 - Error: 0.075345
# Iteration 730/1000 - Error: 0.075343
# Iteration 740/1000 - Error: 0.075342
# Iteration 750/1000 - Error: 0.075340
# Iteration 760/1000 - Error: 0.075339
# Iteration 770/1000 - Error: 0.075337
# Iteration 780/1000 - Error: 0.075336
# Iteration 790/1000 - Error: 0.075335
# Iteration 800/1000 - Error: 0.075333
# Iteration 810/1000 - Error: 0.075332
# Iteration 820/1000 - Error: 0.075331
# Iteration 830/1000 - Error: 0.075330
# Iteration 840/1000 - Error: 0.075329
# Iteration 850/1000 - Error: 0.075328
# Iteration 860/1000 - Error: 0.075328
# Iteration 870/1000 - Error: 0.075327
# Iteration 880/1000 - Error: 0.075326
# Iteration 890/1000 - Error: 0.075326
# Iteration 900/1000 - Error: 0.075325
# Iteration 910/1000 - Error: 0.075324
# Iteration 920/1000 - Error: 0.075324
# Iteration 930/1000 - Error: 0.075323
# Iteration 940/1000 - Error: 0.075323
# Iteration 950/1000 - Error: 0.075322
# Iteration 960/1000 - Error: 0.075322
# Iteration 970/1000 - Error: 0.075321
# Iteration 980/1000 - Error: 0.075320
# Iteration 990/1000 - Error: 0.075320
# Iteration 1000/1000 - Error: 0.075320
# Iteration 10/1000 - Error: 0.094075
# Iteration 20/1000 - Error: 0.091709
# Iteration 30/1000 - Error: 0.088721
# Iteration 40/1000 - Error: 0.085741
# Iteration 50/1000 - Error: 0.083189
# Iteration 60/1000 - Error: 0.081230
# Iteration 70/1000 - Error: 0.079833
# Iteration 80/1000 - Error: 0.078868
# Iteration 90/1000 - Error: 0.078191
# Iteration 100/1000 - Error: 0.077687
# Iteration 110/1000 - Error: 0.077288
# Iteration 120/1000 - Error: 0.076956
# Iteration 130/1000 - Error: 0.076675
# Iteration 140/1000 - Error: 0.076438
# Iteration 150/1000 - Error: 0.076242
# Iteration 160/1000 - Error: 0.076084
# Iteration 170/1000 - Error: 0.075957
# Iteration 180/1000 - Error: 0.075859
# Iteration 190/1000 - Error: 0.075783
# Iteration 200/1000 - Error: 0.075725
# Iteration 210/1000 - Error: 0.075681
# Iteration 220/1000 - Error: 0.075647
# Iteration 230/1000 - Error: 0.075620
# Iteration 240/1000 - Error: 0.075598
# Iteration 250/1000 - Error: 0.075580
# Iteration 260/1000 - Error: 0.075563
# Iteration 270/1000 - Error: 0.075546
# Iteration 280/1000 - Error: 0.075530
# Iteration 290/1000 - Error: 0.075515
# Iteration 300/1000 - Error: 0.075499
# Iteration 310/1000 - Error: 0.075484
# Iteration 320/1000 - Error: 0.075469
# Iteration 330/1000 - Error: 0.075455
# Iteration 340/1000 - Error: 0.075442
# Iteration 350/1000 - Error: 0.075430
# Iteration 360/1000 - Error: 0.075420
# Iteration 370/1000 - Error: 0.075411
# Iteration 380/1000 - Error: 0.075403
# Iteration 390/1000 - Error: 0.075397
# Iteration 400/1000 - Error: 0.075391
# Iteration 410/1000 - Error: 0.075387
# Iteration 420/1000 - Error: 0.075383
# Iteration 430/1000 - Error: 0.075379
# Iteration 440/1000 - Error: 0.075376
# Iteration 450/1000 - Error: 0.075373
# Iteration 460/1000 - Error: 0.075370
# Iteration 470/1000 - Error: 0.075367
# Iteration 480/1000 - Error: 0.075365
# Iteration 490/1000 - Error: 0.075362
# Iteration 500/1000 - Error: 0.075359
# Iteration 510/1000 - Error: 0.075357
# Iteration 520/1000 - Error: 0.075354
# Iteration 530/1000 - Error: 0.075352
# Iteration 540/1000 - Error: 0.075350
# Iteration 550/1000 - Error: 0.075348
# Iteration 560/1000 - Error: 0.075346
# Iteration 570/1000 - Error: 0.075345
# Iteration 580/1000 - Error: 0.075343
# Iteration 590/1000 - Error: 0.075342
# Iteration 600/1000 - Error: 0.075340
# Iteration 610/1000 - Error: 0.075339
# Iteration 620/1000 - Error: 0.075338
# Iteration 630/1000 - Error: 0.075337
# Iteration 640/1000 - Error: 0.075336
# Iteration 650/1000 - Error: 0.075335
# Iteration 660/1000 - Error: 0.075334
# Iteration 670/1000 - Error: 0.075334
# Iteration 680/1000 - Error: 0.075333
# Iteration 690/1000 - Error: 0.075332
# Iteration 700/1000 - Error: 0.075331
# Iteration 710/1000 - Error: 0.075331
# Iteration 720/1000 - Error: 0.075330
# Iteration 730/1000 - Error: 0.075329
# Iteration 740/1000 - Error: 0.075329
# Iteration 750/1000 - Error: 0.075328
# Iteration 760/1000 - Error: 0.075327
# Iteration 770/1000 - Error: 0.075327
# Iteration 780/1000 - Error: 0.075326
# Iteration 790/1000 - Error: 0.075326
# Iteration 800/1000 - Error: 0.075325
# Iteration 810/1000 - Error: 0.075325
# Iteration 820/1000 - Error: 0.075325
# Iteration 830/1000 - Error: 0.075324
# Iteration 840/1000 - Error: 0.075324
# Iteration 850/1000 - Error: 0.075324
# Iteration 860/1000 - Error: 0.075323
# Iteration 870/1000 - Error: 0.075323
# Iteration 880/1000 - Error: 0.075323
# Iteration 890/1000 - Error: 0.075322
# Iteration 900/1000 - Error: 0.075322
# Iteration 910/1000 - Error: 0.075322
# Iteration 920/1000 - Error: 0.075321
# Iteration 930/1000 - Error: 0.075321
# Iteration 940/1000 - Error: 0.075321
# Iteration 950/1000 - Error: 0.075321
# Iteration 960/1000 - Error: 0.075320
# Iteration 970/1000 - Error: 0.075320
# Iteration 980/1000 - Error: 0.075320
# Iteration 990/1000 - Error: 0.075320
# Iteration 1000/1000 - Error: 0.075319
# Iteration 10/1000 - Error: 0.090331
# Iteration 20/1000 - Error: 0.083877
# Iteration 30/1000 - Error: 0.079949
# Iteration 40/1000 - Error: 0.078136
# Iteration 50/1000 - Error: 0.077179
# Iteration 60/1000 - Error: 0.076551
# Iteration 70/1000 - Error: 0.076134
# Iteration 80/1000 - Error: 0.075879
# Iteration 90/1000 - Error: 0.075732
# Iteration 100/1000 - Error: 0.075649
# Iteration 110/1000 - Error: 0.075596
# Iteration 120/1000 - Error: 0.075555
# Iteration 130/1000 - Error: 0.075517
# Iteration 140/1000 - Error: 0.075481
# Iteration 150/1000 - Error: 0.075450
# Iteration 160/1000 - Error: 0.075424
# Iteration 170/1000 - Error: 0.075405
# Iteration 180/1000 - Error: 0.075391
# Iteration 190/1000 - Error: 0.075381
# Iteration 200/1000 - Error: 0.075372
# Iteration 210/1000 - Error: 0.075365
# Iteration 220/1000 - Error: 0.075358
# Iteration 230/1000 - Error: 0.075352
# Iteration 240/1000 - Error: 0.075346
# Iteration 250/1000 - Error: 0.075341
# Iteration 260/1000 - Error: 0.075337
# Iteration 270/1000 - Error: 0.075333
# Iteration 280/1000 - Error: 0.075330
# Iteration 290/1000 - Error: 0.075328
# Iteration 300/1000 - Error: 0.075325
# Iteration 310/1000 - Error: 0.075323
# Iteration 320/1000 - Error: 0.075321
# Iteration 330/1000 - Error: 0.075319
# Iteration 340/1000 - Error: 0.075317
# Iteration 350/1000 - Error: 0.075316
# Iteration 360/1000 - Error: 0.075315
# Iteration 370/1000 - Error: 0.075313
# Iteration 380/1000 - Error: 0.075312
# Iteration 390/1000 - Error: 0.075311
# Iteration 400/1000 - Error: 0.075310
# Iteration 410/1000 - Error: 0.075309
# Iteration 420/1000 - Error: 0.075308
# Iteration 430/1000 - Error: 0.075308
# Iteration 440/1000 - Error: 0.075307
# Iteration 450/1000 - Error: 0.075306
# Iteration 460/1000 - Error: 0.075306
# Iteration 470/1000 - Error: 0.075305
# Iteration 480/1000 - Error: 0.075304
# Iteration 490/1000 - Error: 0.075304
# Iteration 500/1000 - Error: 0.075303
# Iteration 510/1000 - Error: 0.075303
# Iteration 520/1000 - Error: 0.075303
# Iteration 530/1000 - Error: 0.075302
# Iteration 540/1000 - Error: 0.075302
# Iteration 550/1000 - Error: 0.075301
# Iteration 560/1000 - Error: 0.075301
# Iteration 570/1000 - Error: 0.075301
# Iteration 580/1000 - Error: 0.075300
# Iteration 590/1000 - Error: 0.075300
# Iteration 600/1000 - Error: 0.075300
# Iteration 610/1000 - Error: 0.075300
# Iteration 620/1000 - Error: 0.075299
# Iteration 630/1000 - Error: 0.075299
# Iteration 640/1000 - Error: 0.075299
# Iteration 650/1000 - Error: 0.075299
# Iteration 660/1000 - Error: 0.075299
# Iteration 670/1000 - Error: 0.075298
# Iteration 680/1000 - Error: 0.075298
# Iteration 690/1000 - Error: 0.075298
# Iteration 700/1000 - Error: 0.075298
# Iteration 710/1000 - Error: 0.075298
# Iteration 720/1000 - Error: 0.075297
# Iteration 730/1000 - Error: 0.075297
# Iteration 740/1000 - Error: 0.075297
# Iteration 750/1000 - Error: 0.075297
# Iteration 760/1000 - Error: 0.075297
# Iteration 770/1000 - Error: 0.075297
# Iteration 780/1000 - Error: 0.075297
# Iteration 790/1000 - Error: 0.075297
# Iteration 800/1000 - Error: 0.075296
# Iteration 810/1000 - Error: 0.075296
# Iteration 820/1000 - Error: 0.075296
# Iteration 830/1000 - Error: 0.075296
# Iteration 840/1000 - Error: 0.075296
# Iteration 850/1000 - Error: 0.075296
# Iteration 860/1000 - Error: 0.075296
# Iteration 870/1000 - Error: 0.075296
# Iteration 880/1000 - Error: 0.075296
# Iteration 890/1000 - Error: 0.075296
# Iteration 900/1000 - Error: 0.075296
# Iteration 910/1000 - Error: 0.075295
# Iteration 920/1000 - Error: 0.075295
# Iteration 930/1000 - Error: 0.075295
# Iteration 940/1000 - Error: 0.075295
# Iteration 950/1000 - Error: 0.075295
# Iteration 960/1000 - Error: 0.075295
# Iteration 970/1000 - Error: 0.075295
# Iteration 980/1000 - Error: 0.075295
# Iteration 990/1000 - Error: 0.075295
# Iteration 1000/1000 - Error: 0.075295
# Iteration 10/1000 - Error: 0.087179
# Iteration 20/1000 - Error: 0.080437
# Iteration 30/1000 - Error: 0.077978
# Iteration 40/1000 - Error: 0.076873
# Iteration 50/1000 - Error: 0.076250
# Iteration 60/1000 - Error: 0.075932
# Iteration 70/1000 - Error: 0.075782
# Iteration 80/1000 - Error: 0.075700
# Iteration 90/1000 - Error: 0.075640
# Iteration 100/1000 - Error: 0.075586
# Iteration 110/1000 - Error: 0.075542
# Iteration 120/1000 - Error: 0.075511
# Iteration 130/1000 - Error: 0.075491
# Iteration 140/1000 - Error: 0.075476
# Iteration 150/1000 - Error: 0.075464
# Iteration 160/1000 - Error: 0.075454
# Iteration 170/1000 - Error: 0.075445
# Iteration 180/1000 - Error: 0.075437
# Iteration 190/1000 - Error: 0.075431
# Iteration 200/1000 - Error: 0.075426
# Iteration 210/1000 - Error: 0.075422
# Iteration 220/1000 - Error: 0.075419
# Iteration 230/1000 - Error: 0.075415
# Iteration 240/1000 - Error: 0.075413
# Iteration 250/1000 - Error: 0.075410
# Iteration 260/1000 - Error: 0.075408
# Iteration 270/1000 - Error: 0.075406
# Iteration 280/1000 - Error: 0.075404
# Iteration 290/1000 - Error: 0.075403
# Iteration 300/1000 - Error: 0.075401
# Iteration 310/1000 - Error: 0.075400
# Iteration 320/1000 - Error: 0.075399
# Iteration 330/1000 - Error: 0.075398
# Iteration 340/1000 - Error: 0.075397
# Iteration 350/1000 - Error: 0.075396
# Iteration 360/1000 - Error: 0.075395
# Iteration 370/1000 - Error: 0.075395
# Iteration 380/1000 - Error: 0.075394
# Iteration 390/1000 - Error: 0.075393
# Iteration 400/1000 - Error: 0.075393
# Iteration 410/1000 - Error: 0.075392
# Iteration 420/1000 - Error: 0.075392
# Iteration 430/1000 - Error: 0.075391
# Iteration 440/1000 - Error: 0.075391
# Iteration 450/1000 - Error: 0.075391
# Iteration 460/1000 - Error: 0.075390
# Iteration 470/1000 - Error: 0.075390
# Iteration 480/1000 - Error: 0.075390
# Iteration 490/1000 - Error: 0.075389
# Iteration 500/1000 - Error: 0.075389
# Iteration 510/1000 - Error: 0.075389
# Iteration 520/1000 - Error: 0.075388
# Iteration 530/1000 - Error: 0.075388
# Iteration 540/1000 - Error: 0.075388
# Iteration 550/1000 - Error: 0.075388
# Iteration 560/1000 - Error: 0.075388
# Iteration 570/1000 - Error: 0.075387
# Iteration 580/1000 - Error: 0.075387
# Iteration 590/1000 - Error: 0.075387
# Iteration 600/1000 - Error: 0.075387
# Iteration 610/1000 - Error: 0.075387
# Iteration 620/1000 - Error: 0.075387
# Iteration 630/1000 - Error: 0.075386
# Iteration 640/1000 - Error: 0.075386
# Iteration 650/1000 - Error: 0.075386
# Iteration 660/1000 - Error: 0.075386
# Iteration 670/1000 - Error: 0.075386
# Iteration 680/1000 - Error: 0.075386
# Iteration 690/1000 - Error: 0.075386
# Iteration 700/1000 - Error: 0.075386
# Iteration 710/1000 - Error: 0.075386
# Iteration 720/1000 - Error: 0.075385
# Iteration 730/1000 - Error: 0.075385
# Iteration 740/1000 - Error: 0.075385
# Iteration 750/1000 - Error: 0.075385
# Iteration 760/1000 - Error: 0.075385
# Iteration 770/1000 - Error: 0.075385
# Iteration 780/1000 - Error: 0.075385
# Iteration 790/1000 - Error: 0.075385
# Iteration 800/1000 - Error: 0.075385
# Iteration 810/1000 - Error: 0.075385
# Iteration 820/1000 - Error: 0.075385
# Iteration 830/1000 - Error: 0.075385
# Iteration 840/1000 - Error: 0.075385
# Iteration 850/1000 - Error: 0.075385
# Iteration 860/1000 - Error: 0.075384
# Iteration 870/1000 - Error: 0.075384
# Iteration 880/1000 - Error: 0.075384
# Iteration 890/1000 - Error: 0.075384
# Iteration 900/1000 - Error: 0.075384
# Iteration 910/1000 - Error: 0.075384
# Iteration 920/1000 - Error: 0.075384
# Iteration 930/1000 - Error: 0.075384
# Iteration 940/1000 - Error: 0.075384
# Iteration 950/1000 - Error: 0.075384
# Iteration 960/1000 - Error: 0.075384
# Iteration 970/1000 - Error: 0.075384
# Iteration 980/1000 - Error: 0.075384
# Iteration 990/1000 - Error: 0.075384
# Iteration 1000/1000 - Error: 0.075384
# Iteration 10/1000 - Error: 0.087030
# Iteration 20/1000 - Error: 0.083968
# Iteration 30/1000 - Error: 0.083064
# Iteration 40/1000 - Error: 0.082810
# Iteration 50/1000 - Error: 0.082717
# Iteration 60/1000 - Error: 0.082689
# Iteration 70/1000 - Error: 0.082681
# Iteration 80/1000 - Error: 0.082677
# Iteration 90/1000 - Error: 0.082674
# Iteration 100/1000 - Error: 0.082672
# Iteration 110/1000 - Error: 0.082671
# Iteration 120/1000 - Error: 0.082670
# Iteration 130/1000 - Error: 0.082669
# Iteration 140/1000 - Error: 0.082669
# Iteration 150/1000 - Error: 0.082669
# Iteration 160/1000 - Error: 0.082668
# Iteration 170/1000 - Error: 0.082668
# Iteration 180/1000 - Error: 0.082668
# Iteration 190/1000 - Error: 0.082668
# Iteration 200/1000 - Error: 0.082667
# Iteration 210/1000 - Error: 0.082667
# Iteration 220/1000 - Error: 0.082667
# Iteration 230/1000 - Error: 0.082667
# Iteration 240/1000 - Error: 0.082667
# Iteration 250/1000 - Error: 0.082667
# Iteration 260/1000 - Error: 0.082667
# Iteration 270/1000 - Error: 0.082667
# Iteration 280/1000 - Error: 0.082667
# Iteration 290/1000 - Error: 0.082667
# Iteration 300/1000 - Error: 0.082667
# Iteration 310/1000 - Error: 0.082667
# Iteration 320/1000 - Error: 0.082667
# Iteration 330/1000 - Error: 0.082667
# Iteration 340/1000 - Error: 0.082667
# Iteration 350/1000 - Error: 0.082667
# Iteration 360/1000 - Error: 0.082667
# Iteration 370/1000 - Error: 0.082667
# Iteration 380/1000 - Error: 0.082667
# Iteration 390/1000 - Error: 0.082667
# Iteration 400/1000 - Error: 0.082667
# Iteration 410/1000 - Error: 0.082667
# Iteration 420/1000 - Error: 0.082667
# Iteration 430/1000 - Error: 0.082667
# Iteration 440/1000 - Error: 0.082667
# Iteration 450/1000 - Error: 0.082667
# Iteration 460/1000 - Error: 0.082667
# Iteration 470/1000 - Error: 0.082667
# Iteration 480/1000 - Error: 0.082667
# Iteration 490/1000 - Error: 0.082667
# Iteration 500/1000 - Error: 0.082667
# Iteration 510/1000 - Error: 0.082667
# Iteration 520/1000 - Error: 0.082667
# Iteration 530/1000 - Error: 0.082667
# Iteration 540/1000 - Error: 0.082667
# Iteration 550/1000 - Error: 0.082667
# Iteration 560/1000 - Error: 0.082667
# Iteration 570/1000 - Error: 0.082667
# Iteration 580/1000 - Error: 0.082667
# Iteration 590/1000 - Error: 0.082667
# Iteration 600/1000 - Error: 0.082667
# Iteration 610/1000 - Error: 0.082667
# Iteration 620/1000 - Error: 0.082667
# Iteration 630/1000 - Error: 0.082667
# Iteration 640/1000 - Error: 0.082667
# Iteration 650/1000 - Error: 0.082667
# Iteration 660/1000 - Error: 0.082667
# Iteration 670/1000 - Error: 0.082667
# Iteration 680/1000 - Error: 0.082667
# Iteration 690/1000 - Error: 0.082667
# Iteration 700/1000 - Error: 0.082667
# Iteration 710/1000 - Error: 0.082667
# Iteration 720/1000 - Error: 0.082667
# Iteration 730/1000 - Error: 0.082667
# Iteration 740/1000 - Error: 0.082667
# Iteration 750/1000 - Error: 0.082667
# Iteration 760/1000 - Error: 0.082667
# Iteration 770/1000 - Error: 0.082667
# Iteration 780/1000 - Error: 0.082667
# Iteration 790/1000 - Error: 0.082667
# Iteration 800/1000 - Error: 0.082667
# Iteration 810/1000 - Error: 0.082667
# Iteration 820/1000 - Error: 0.082667
# Iteration 830/1000 - Error: 0.082667
# Iteration 840/1000 - Error: 0.082667
# Iteration 850/1000 - Error: 0.082667
# Iteration 860/1000 - Error: 0.082667
# Iteration 870/1000 - Error: 0.082667
# Iteration 880/1000 - Error: 0.082667
# Iteration 890/1000 - Error: 0.082667
# Iteration 900/1000 - Error: 0.082667
# Iteration 910/1000 - Error: 0.082667
# Iteration 920/1000 - Error: 0.082667
# Iteration 930/1000 - Error: 0.082667
# Iteration 940/1000 - Error: 0.082667
# Iteration 950/1000 - Error: 0.082667
# Iteration 960/1000 - Error: 0.082667
# Iteration 970/1000 - Error: 0.082667
# Iteration 980/1000 - Error: 0.082667
# Iteration 990/1000 - Error: 0.082667
# Iteration 1000/1000 - Error: 0.082667
